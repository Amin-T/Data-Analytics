# %% [markdown]
# I use wordcloud package on sample text data and pandas dataframe to generate Word Cloud charts.

# %%
import numpy as np
import pandas as pd
from PIL import Image # converting images into arrays
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# import wordcloud package and its set of stopwords
from wordcloud import WordCloud, STOPWORDS

# %% [markdown]
# ## Word Cloud from .txt file

# %%
article = open('WHO-2019-nCoV-IPC-2020.4-eng.txt', encoding='utf-8', mode='r').read()

# %%
stopwords = set(STOPWORDS)

# instantiate a word cloud object
covid_wc = WordCloud(
    background_color='white',
    max_words=500
)

# generate the word cloud
covid_wc.generate(article)

# %%
fig = plt.figure(figsize=(16,12))

# display the word cloud
plt.imshow(covid_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
fig.savefig("covid_wc.jpg", dpi=600)

# %% [markdown]
# # Word cloud based on word importance

# %%
dict = {'Words': ['Innovation', 'Technology', 'ML', 'Python', 'Excel', 'Finance', 'Marketing', 'Business', 'Codes', 'Science',
                 '2020', 'Creativity', 'Belgium', 'Management', 'Statistics', 'Engineering', 'Data', 'Analyst', 'GitHub', 'Environment'],
       'Importance': np.random.RandomState(seed=100).randint(10, 100, 20)}
df = pd.DataFrame(dict)

# %%
df.set_index('Words', inplace=True)

# %%
# Duplicate each word based on its importance in a string.
word_string = ''
for word in df.index.values:
    word_string = word_string + ((word + ' ') * df.loc[word, 'Importance'])

# %%
# create the word cloud
wordcloud = WordCloud(background_color='white').generate(word_string)

# display the cloud
fig = plt.figure(figsize=(5,5), dpi=200)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
